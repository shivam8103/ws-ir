# %% [markdown]
# # Chapter 1:
# - OSI Model,
# - Layered Architecture,
# - Layer-to-Layer Communication,
# - IP Protocol Suite,
# - Comparison between OSI and TCP/IP Protocol Suite

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 1.**
# A networking company proposes a new, "monolithic" (single-layer) protocol stack. They claim it will be much faster because it eliminates the overhead of passing data between layers (no encapsulation/decapsulation). Discuss the **major disadvantages** of this approach compared to a layered model like OSI or TCP/IP, focusing on interoperability, maintenance, and standardization.

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 2.**
# A web browser is sending a 100-byte HTTP GET request. This message must be processed by the TCP/IP stack. Assume the following:
# * **TCP header:** 20 bytes
# * **IP header:** 20 bytes
# * **Ethernet header & trailer:** 18 bytes
#
#
# Determine:
# - The size of the **TCP segment** created by the Transport layer.
# - The size of the **IP datagram** created by the Internet layer.
# - The size of the **Ethernet frame** transmitted by the Link layer.
# - What percentage of the final transmitted frame is **protocol overhead** (i.e., not the original 100-byte application data)?

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 3.**
# The TCP/IP model is often described as an "hourglass" or "narrow waist" model, with the IP protocol being the "narrow waist."
#
# - What does this analogy mean?
#
# - Discuss the **primary design advantage** of this architecture. How did this specific design choice lead to the massive scalability and innovation (in both applications and link technologies) of the Internet?

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 4.**
# Explain the fundamental difference between a **service** and a **protocol** in a layered architecture. Use the relationship between the TCP/IP **Transport layer** and **Internet layer** as a specific example to illustrate your answer (i.e., how does one *provide a service* to the layer above it, while *using a protocol* to talk to its peer?).

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 5.**
# A host computer receives an Ethernet frame. The frame's "Type" field has a value of `0x0800`. The resulting IP datagram's "Protocol" field has a value of `6`. The resulting TCP segment's "Destination Port" field has a value of `443`.
# * Explain the process of **demultiplexing** (decapsulation).
# * How does the receiving host use *each* of these three values to correctly deliver the payload to the intended application (e.g., a secure web browser)?

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 6.**
# The OSI model formally defines a **Session layer (Layer 5)** and a **Presentation layer (Layer 6)**. The TCP/IP model combines these functions into its Application layer.
# - What are the main responsibilities of the OSI Session and Presentation layers?
# - Discuss the **practical advantages and disadvantages** of the TCP/IP model's "simpler" approach.

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 7.**
# The Internet layer (IP) of the TCP/IP suite provides a "best-effort," connectionless datagram service. However, many applications (like file transfers and web browsing) require reliable, connection-oriented service. Discuss how the TCP/IP suite **resolves this conflict**. Which layer is responsible for adding reliability, and what key functions does it perform that IP does not?

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 8.**
# The TCP/IP model *could* have been designed to only run connection-oriented protocols (like TCP) directly on top of IP, without offering a connectionless option (like UDP). Discuss the **performance implications** of this hypothetical design. Which modern applications would be severely impacted or rendered unusable, and why?

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 9.**
# Imagine a network where the **Transport layer (TCP/UDP) did not exist**. Applications had to write their data directly to the IP layer. Discuss the specific problems an application developer would have to solve *manually* for every application they build, which are currently handled by the Transport layer.

# %% [markdown]
# ---

# %% [markdown]
# ## **Ques. 10.**
# The OSI model was designed *before* its protocols were implemented (a prescriptive approach), while the TCP/IP model was designed *after* its core protocols (TCP, IP) were already in use (a descriptive approach). Discuss how this difference in philosophy and timing led to the TCP/IP suite becoming the practical, dominant standard of the Internet, even though the OSI model is often considered more comprehensive.

# %% [markdown]
# ---
