# %% [markdown]
# ## MIMO
#
# - Multiple input and multiple output..
#
# - MIMO (multiple input, multiple output) is an antenna technology for wireless communications in which multiple antennas are used at both the source (transmitter) and the destination (receiver). The antennas at each end of the communications circuit are combined to minimize errors, optimize data speed and improve the capacity of radio transmissions by enabling data to travel over many signal paths at the same time.
#
# - Multiple Input = Multipl transmitting antenna
# - Multiple Output = Multipl receiving  antenna
#
# - So MIMO is combination of multiple transmit and multiple receiving antenna
#
# ## Block diagram of MIMO
#
# <img src="img/MIMO1.png" width="900">

# %% [markdown]
# MIMO increase the data rate, by transmitting several information stream in parallel.
#
# this property is known as spatial multiplexing
#
# ### Spatial Multiplexing
#
#
# <img src="img/MIMO2.png" width="900">

# %% [markdown]
# ## SUMIMO vs MU-MIMO
#
# <img src="img/MIMO3.png" width="900">
